# %%
import numpy

# %%
numpy.loadtxt('survey_data_clean.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-a6a749e015af> in <module>()
# ----> 1 numpy.loadtxt('survey_data_clean.csv', delimiter=',')
#
# C:\Users\Max\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     931             # Then pack it according to the dtype's nesting
#     932             items = pack_items(items, packing)
#
# C:\Users\Max\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     928
#     929             # Convert each value according to its column and store
# --> 930             items = [conv(val) for (conv, val) in zip(converters, vals)]
# ...

# %%
import pandas

# %%
df = pandas.read_csv('Survey_data_clean.csv')
df
# Out:
#     Day  Month  Year Species  Plot  Sex  Weight Calibrated
# 0    16      7  2013      DM     2    F  -99999          Y
# 1    16      7  2013      DM     7    M      33          Y
# 2    16      7  2013      DM     3    M  -99999          Y
# 3    16      7  2013      DM     1    M  -99999          Y
# 4    18      7  2013      DM     3    M      40          Y
# 5    18      7  2013      DM     7    M      48          Y
# 6    18      7  2013      DM     4    F      29          Y
# 7    18      7  2013      DM     4    F      46          Y
# 8    18      7  2013      DM     7    M      36          Y
# 9    18      7  2013      DM     7    F      35          Y
# 10   18      7  2013      DM     8    F      22          Y
# 11   18      7  2013      DM     7    F      42          Y
# 12   18      7  2013      DM     4    F      41          Y
# 13   18      7  2013      DM     6    F      37          Y
# 14   19      8  2013      DO     8    F      52          Y
# ...

# %%
numpy.mean(df.Weight[df.Sex == 'F'])
